# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df= pd.read_csv("Personal.csv")

# %%
df
# Out:
#     ID    First_name   Last_name   Age Subject  Marks
# 0    1         Vinit    Verulkar  21.0      IS     99
# 1    2          Yash       Limje  20.0   AR/VR     67
# 2    3        Gautam   Hargunani  20.0   AR/VR     89
# 3    4        Nilesh   Bombatkar  22.0      CC     78
# 4    5       Dhiraj    Hargunani   NaN      CC     56
# 5    6         Rohit   Hargunani  19.0      IS   1000
# 6    7         Mohit     Nikhade  23.0      IS     78
# 7    8  Gopalkrushna       Kolhe  21.0      CC     89
# 8    9         Sumit         Raj  17.0      CC     56
# 9   10            Om      Mihani  24.0      IS     89
# 10  11       Harshit  Khandelwal  24.0   AR/VR     78
# 11  12       Atharva     Chandak  15.0      CC     75
# 12  13         Tejas    Deshmukh  21.0      IS     95
# 13  14      Bhavesh        Ingle  22.0   AR/VR     68
# 14  15    Prathamesh    Kharpate  25.0      CC     35
# 15  16        kaVERI        RAUT  20.0      CC     78

# %%
df3=df.merge(df2, how="right")

# %%
df3df2
# Out:
#     ID First_name      Last_name   Age Subject  Marks
# 0    1      Vinit       Verulkar  21.0      IS     99
# 1    2     Aditya      Shewalkar  22.0   AR/VR     78
# 2    3      Sagar          Patil  23.0   AR/VR     76
# 3    4    Atharva       Kulkarni  22.0   AR/VR     98
# 4    5    Sandhya       Rakhunde  21.0      CC     57
# 5    6     Kaveri           Raut  20.0      CC    456
# 6    7       Riya          Muley  21.0      CC     57
# 7    8     Nimish       Sanghwai  21.0      IS     78
# 8    9     Devraj        Shetake  23.0      CC     35
# 9   10    Sumeet           Ubale  21.0      CC     68
# 10  11      Niraj     Waghchoure  23.0      CC     57
# 11  12      Arnav       Waghulde  22.0      IS     89
# 12  13    Mahadev        Wardule  22.0      CC     45
# 13  14    Vinayki          Dalvi  24.0      CC     89
# 14  15   Kaustubh    Suryavanshi  25.0      IS     68
# 15  16    Chinmay      Choudhary  19.0      IS     89
# ...

# %%
df4=df.merge(df2, how="left");

# %%
df4
# Out:
#     ID    First_name   Last_name   Age Subject  Marks
# 0    1         Vinit    Verulkar  21.0      IS     99
# 1    2          Yash       Limje  20.0   AR/VR     67
# 2    3        Gautam   Hargunani  20.0   AR/VR     89
# 3    4        Nilesh   Bombatkar  22.0      CC     78
# 4    5       Dhiraj    Hargunani   NaN      CC     56
# 5    6         Rohit   Hargunani  19.0      IS   1000
# 6    7         Mohit     Nikhade  23.0      IS     78
# 7    8  Gopalkrushna       Kolhe  21.0      CC     89
# 8    9         Sumit         Raj  17.0      CC     56
# 9   10            Om      Mihani  24.0      IS     89
# 10  11       Harshit  Khandelwal  24.0   AR/VR     78
# 11  12       Atharva     Chandak  15.0      CC     75
# 12  13         Tejas    Deshmukh  21.0      IS     95
# 13  14      Bhavesh        Ingle  22.0   AR/VR     68
# 14  15    Prathamesh    Kharpate  25.0      CC     35
# 15  16        kaVERI        RAUT  20.0      CC     78

# %%
df5= df.merge(df2, how="cross")

# %%
df5
# Out:
#      ID_x First_name_x Last_name_x  Age_x Subject_x  Marks_x  ID_y  \
# 0       1        Vinit    Verulkar   21.0        IS       99     1
# 1       1        Vinit    Verulkar   21.0        IS       99     2
# 2       1        Vinit    Verulkar   21.0        IS       99     3
# 3       1        Vinit    Verulkar   21.0        IS       99     4
# 4       1        Vinit    Verulkar   21.0        IS       99     5
# ..    ...          ...         ...    ...       ...      ...   ...
# 491    16       kaVERI        RAUT   20.0        CC       78    27
# 492    16       kaVERI        RAUT   20.0        CC       78    28
# 493    16       kaVERI        RAUT   20.0        CC       78    29
# 494    16       kaVERI        RAUT   20.0        CC       78    30
# 495    16       kaVERI        RAUT   20.0        CC       78    31
#
#     First_name_y    Last_name_y  Age_y Subject_y  Marks_y
# 0          Vinit       Verulkar   21.0        IS       99
# ...

# %%
df2= pd.read_csv("Personal1.csv")

# %%
df = df.style.set_properties(subset=['Last_name'],**{'text-align': 'left'})

# %%
df
# Out:
# <style type="text/css">
# #T_f4b9e_row0_col2, #T_f4b9e_row1_col2, #T_f4b9e_row2_col2, #T_f4b9e_row3_col2, #T_f4b9e_row4_col2, #T_f4b9e_row5_col2, #T_f4b9e_row6_col2, #T_f4b9e_row7_col2, #T_f4b9e_row8_col2, #T_f4b9e_row9_col2, #T_f4b9e_row10_col2, #T_f4b9e_row11_col2, #T_f4b9e_row12_col2, #T_f4b9e_row13_col2, #T_f4b9e_row14_col2, #T_f4b9e_row15_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_f4b9e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4b9e_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_f4b9e_level0_col1" class="col_heading level0 col1" >First_name</th>
#       <th id="T_f4b9e_level0_col2" class="col_heading level0 col2" >Last_name</th>
#       <th id="T_f4b9e_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_f4b9e_level0_col4" class="col_heading level0 col4" >Subject</th>
#       <th id="T_f4b9e_level0_col5" class="col_heading level0 col5" >Marks</th>
#     </tr>
# ...

# %%
df =df.style.set_properties(**{'text-align': 'right'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df =df.style.set_properties(**{'text-align': 'right'})
#
# AttributeError: 'Styler' object has no attribute 'style'

# %%
df
# Out:
#     ID    First_name   Last_name   Age Subject  Marks
# 0    1         Vinit    Verulkar  21.0      IS     99
# 1    2          Yash       Limje  20.0   AR/VR     67
# 2    3        Gautam   Hargunani  20.0   AR/VR     89
# 3    4        Nilesh   Bombatkar  22.0      CC     78
# 4    5       Dhiraj    Hargunani   NaN      CC     56
# 5    6         Rohit   Hargunani  19.0      IS   1000
# 6    7         Mohit     Nikhade  23.0      IS     78
# 7    8  Gopalkrushna       Kolhe  21.0      CC     89
# 8    9         Sumit         Raj  17.0      CC     56
# 9   10            Om      Mihani  24.0      IS     89
# 10  11       Harshit  Khandelwal  24.0   AR/VR     78
# 11  12       Atharva     Chandak  15.0      CC     75
# 12  13         Tejas    Deshmukh  21.0      IS     95
# 13  14      Bhavesh        Ingle  22.0   AR/VR     68
# 14  15    Prathamesh    Kharpate  25.0      CC     35
# 15  16        kaVERI        RAUT  20.0      CC     78

# %%
df.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])

# %%
df2
# Out:
#     ID First_name      Last_name   Age Subject  Marks
# 0    1      Vinit       Verulkar  21.0      IS     99
# 1    2     Aditya      Shewalkar  22.0   AR/VR     78
# 2    3      Sagar          Patil  23.0   AR/VR     76
# 3    4    Atharva       Kulkarni  22.0   AR/VR     98
# 4    5    Sandhya       Rakhunde  21.0      CC     57
# 5    6     Kaveri           Raut  20.0      CC     78
# 6    7       Riya          Muley  21.0      CC     57
# 7    8     Nimish       Sanghwai  21.0      IS     78
# 8    9     Devraj        Shetake  23.0      CC     35
# 9   10    Sumeet           Ubale  21.0      CC     68
# 10  11      Niraj     Waghchoure  23.0      CC     57
# 11  12      Arnav       Waghulde  22.0      IS     89
# 12  13    Mahadev        Wardule  22.0      CC     45
# 13  14    Vinayki          Dalvi  24.0      CC     89
# 14  15   Kaustubh    Suryavanshi  25.0      IS     68
# 15  16    Chinmay      Choudhary  19.0      IS     89
# ...

# %%
df2.style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align', 'left')] ) ])

# %%
res = pd.concat([df, df2], );

# %%
res
# Out:
#     ID    First_name      Last_name   Age Subject  Marks
# 0    1         Vinit       Verulkar  21.0      IS     99
# 1    2          Yash          Limje  20.0   AR/VR     67
# 2    3        Gautam      Hargunani  20.0   AR/VR     89
# 3    4        Nilesh      Bombatkar  22.0      CC     78
# 4    5       Dhiraj       Hargunani   NaN      CC     56
# 5    6         Rohit      Hargunani  19.0      IS   1000
# 6    7         Mohit        Nikhade  23.0      IS     78
# 7    8  Gopalkrushna          Kolhe  21.0      CC     89
# 8    9         Sumit            Raj  17.0      CC     56
# 9   10            Om         Mihani  24.0      IS     89
# 10  11       Harshit     Khandelwal  24.0   AR/VR     78
# 11  12       Atharva        Chandak  15.0      CC     75
# 12  13         Tejas       Deshmukh  21.0      IS     95
# 13  14      Bhavesh           Ingle  22.0   AR/VR     68
# 14  15    Prathamesh       Kharpate  25.0      CC     35
# ...

# %%
res = pd.concat([df, df2], ignore_index=True);

# %%
res
# Out:
#     ID    First_name      Last_name   Age Subject  Marks
# 0    1         Vinit       Verulkar  21.0      IS     99
# 1    2          Yash          Limje  20.0   AR/VR     67
# 2    3        Gautam      Hargunani  20.0   AR/VR     89
# 3    4        Nilesh      Bombatkar  22.0      CC     78
# 4    5       Dhiraj       Hargunani   NaN      CC     56
# 5    6         Rohit      Hargunani  19.0      IS   1000
# 6    7         Mohit        Nikhade  23.0      IS     78
# 7    8  Gopalkrushna          Kolhe  21.0      CC     89
# 8    9         Sumit            Raj  17.0      CC     56
# 9   10            Om         Mihani  24.0      IS     89
# 10  11       Harshit     Khandelwal  24.0   AR/VR     78
# 11  12       Atharva        Chandak  15.0      CC     75
# 12  13         Tejas       Deshmukh  21.0      IS     95
# 13  14      Bhavesh           Ingle  22.0   AR/VR     68
# 14  15    Prathamesh       Kharpate  25.0      CC     35
# ...

# %%
res= df3.drop_duplicates(subset=['First_name', 'Last_name'], keep='first')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 res= res.drop_duplicates(subset=['First_name', 'Last_name'], keep='first')
#
# NameError: name 'res' is not defined

# %%
res
# Out:
#     ID    First_name      Last_name   Age Subject  Marks
# 0    1         Vinit       Verulkar  21.0      IS     99
# 1    2          Yash          Limje  20.0   AR/VR     67
# 2    3        Gautam      Hargunani  20.0   AR/VR     89
# 3    4        Nilesh      Bombatkar  22.0      CC     78
# 4    5       Dhiraj       Hargunani   NaN      CC     56
# 5    6         Rohit      Hargunani  19.0      IS   1000
# 6    7         Mohit        Nikhade  23.0      IS     78
# 7    8  Gopalkrushna          Kolhe  21.0      CC     89
# 8    9         Sumit            Raj  17.0      CC     56
# 9   10            Om         Mihani  24.0      IS     89
# 10  11       Harshit     Khandelwal  24.0   AR/VR     78
# 11  12       Atharva        Chandak  15.0      CC     75
# 12  13         Tejas       Deshmukh  21.0      IS     95
# 13  14      Bhavesh           Ingle  22.0   AR/VR     68
# 14  15    Prathamesh       Kharpate  25.0      CC     35
# ...

# %%
res['Column1_Upper'] = res['First_name'].astype(str).str.upper()
res['Column2_Upper'] = res['Last_name'].astype(str).str.upper()

# %%
res
# Out:
#     ID    First_name      Last_name   Age Subject  Marks Column1_Upper  \
# 0    1         Vinit       Verulkar  21.0      IS     99         VINIT
# 1    2          Yash          Limje  20.0   AR/VR     67          YASH
# 2    3        Gautam      Hargunani  20.0   AR/VR     89        GAUTAM
# 3    4        Nilesh      Bombatkar  22.0      CC     78        NILESH
# 4    5       Dhiraj       Hargunani   NaN      CC     56       DHIRAJ
# 5    6         Rohit      Hargunani  19.0      IS   1000         ROHIT
# 6    7         Mohit        Nikhade  23.0      IS     78         MOHIT
# 7    8  Gopalkrushna          Kolhe  21.0      CC     89  GOPALKRUSHNA
# 8    9         Sumit            Raj  17.0      CC     56         SUMIT
# 9   10            Om         Mihani  24.0      IS     89            OM
# 10  11       Harshit     Khandelwal  24.0   AR/VR     78       HARSHIT
# 11  12       Atharva        Chandak  15.0      CC     75       ATHARVA
# ...

# %%
res= res.drop_duplicates(subset=['Column1_Upper', 'Column2_Upper'], keep='first')

# %%
del res["Column1_Upper"];

# %%
del res["Column2_Upper"];

# %%
res
# Out:
#     ID    First_name      Last_name   Age Subject  Marks
# 0    1         Vinit       Verulkar  21.0      IS     99
# 1    2          Yash          Limje  20.0   AR/VR     67
# 2    3        Gautam      Hargunani  20.0   AR/VR     89
# 3    4        Nilesh      Bombatkar  22.0      CC     78
# 4    5       Dhiraj       Hargunani   NaN      CC     56
# 5    6         Rohit      Hargunani  19.0      IS   1000
# 6    7         Mohit        Nikhade  23.0      IS     78
# 7    8  Gopalkrushna          Kolhe  21.0      CC     89
# 8    9         Sumit            Raj  17.0      CC     56
# 9   10            Om         Mihani  24.0      IS     89
# 10  11       Harshit     Khandelwal  24.0   AR/VR     78
# 11  12       Atharva        Chandak  15.0      CC     75
# 12  13         Tejas       Deshmukh  21.0      IS     95
# 13  14      Bhavesh           Ingle  22.0   AR/VR     68
# 14  15    Prathamesh       Kharpate  25.0      CC     35
# ...

# %%
means= res['Age'].mean()

# %%
res=res.astype({"Age":'int'})

# %%
res=res.fillna(means)

# %%
res
# Out:
#     ID    First_name      Last_name        Age Subject  Marks
# 0    1         Vinit       Verulkar  21.000000      IS     99
# 1    2          Yash          Limje  20.000000   AR/VR     67
# 2    3        Gautam      Hargunani  20.000000   AR/VR     89
# 3    4        Nilesh      Bombatkar  22.000000      CC     78
# 4    5       Dhiraj       Hargunani  22.142857      CC     56
# 5    6         Rohit      Hargunani  19.000000      IS   1000
# 6    7         Mohit        Nikhade  23.000000      IS     78
# 7    8  Gopalkrushna          Kolhe  21.000000      CC     89
# 8    9         Sumit            Raj  17.000000      CC     56
# 9   10            Om         Mihani  24.000000      IS     89
# 10  11       Harshit     Khandelwal  24.000000   AR/VR     78
# 11  12       Atharva        Chandak  15.000000      CC     75
# 12  13         Tejas       Deshmukh  21.000000      IS     95
# 13  14      Bhavesh           Ingle  22.000000   AR/VR     68
# ...

# %%
df
# Out:
#     ID    First_name   Last_name   Age Subject  Marks
# 0    1         Vinit    Verulkar  21.0      IS     99
# 1    2          Yash       Limje  20.0   AR/VR     67
# 2    3        Gautam   Hargunani  20.0   AR/VR     89
# 3    4        Nilesh   Bombatkar  22.0      CC     78
# 4    5       Dhiraj    Hargunani   NaN      CC     56
# 5    6         Rohit   Hargunani  19.0      IS   1000
# 6    7         Mohit     Nikhade  23.0      IS     78
# 7    8  Gopalkrushna       Kolhe  21.0      CC     89
# 8    9         Sumit         Raj  17.0      CC     56
# 9   10            Om      Mihani  24.0      IS     89
# 10  11       Harshit  Khandelwal  24.0   AR/VR     78
# 11  12       Atharva     Chandak  15.0      CC     75
# 12  13         Tejas    Deshmukh  21.0      IS     95
# 13  14      Bhavesh        Ingle  22.0   AR/VR     68
# 14  15    Prathamesh    Kharpate  25.0      CC     35
# 15  16        kaVERI        RAUT  20.0      CC     78

# %%
df2
# Out:
#     ID First_name      Last_name   Age Subject  Marks
# 0    1      Vinit       Verulkar  21.0      IS     99
# 1    2     Aditya      Shewalkar  22.0   AR/VR     78
# 2    3      Sagar          Patil  23.0   AR/VR     76
# 3    4    Atharva       Kulkarni  22.0   AR/VR     98
# 4    5    Sandhya       Rakhunde  21.0      CC     57
# 5    6     Kaveri           Raut  20.0      CC     78
# 6    7       Riya          Muley  21.0      CC     57
# 7    8     Nimish       Sanghwai  21.0      IS     78
# 8    9     Devraj        Shetake  23.0      CC     35
# 9   10    Sumeet           Ubale  21.0      CC     68
# 10  11      Niraj     Waghchoure  23.0      CC     57
# 11  12      Arnav       Waghulde  22.0      IS     89
# 12  13    Mahadev        Wardule  22.0      CC     45
# 13  14    Vinayki          Dalvi  24.0      CC     89
# 14  15   Kaustubh    Suryavanshi  25.0      IS     68
# 15  16    Chinmay      Choudhary  19.0      IS     89
# ...

# %%
high
# Out:
# 113.5

# %%
low
# Out:
# 21.5

# %%
n= int(res.shape[0]/4);
m= int(3*res.shape[0]/4);
result = res.iloc[:,5:]
result1=result.sort_values("Marks",ignore_index=True)
q1= result1.at[n-1,"Marks"]
q3= result1.at[m-1,"Marks"]
iqr=q3-q1
low= q1-1.5*iqr
high=q3+1.5*iqr
res1=res.copy()

res.loc[res['Marks'] > high, 'Marks'] = high
res.loc[res['Marks'] < low, 'Marks'] = low
res
# Out:
#     ID    First_name      Last_name        Age Subject  Marks
# 0    1         Vinit       Verulkar  21.000000      IS   99.0
# 1    2          Yash          Limje  20.000000   AR/VR   67.0
# 2    3        Gautam      Hargunani  20.000000   AR/VR   89.0
# 3    4        Nilesh      Bombatkar  22.000000      CC   78.0
# 4    5       Dhiraj       Hargunani  22.142857      CC   56.0
# 5    6         Rohit      Hargunani  19.000000      IS  113.5
# 6    7         Mohit        Nikhade  23.000000      IS   78.0
# 7    8  Gopalkrushna          Kolhe  21.000000      CC   89.0
# 8    9         Sumit            Raj  17.000000      CC   56.0
# 9   10            Om         Mihani  24.000000      IS   89.0
# 10  11       Harshit     Khandelwal  24.000000   AR/VR   78.0
# 11  12       Atharva        Chandak  15.000000      CC   75.0
# 12  13         Tejas       Deshmukh  21.000000      IS   95.0
# 13  14      Bhavesh           Ingle  22.000000   AR/VR   68.0
# ...

# %%
res1
# Out:
#     ID    First_name      Last_name        Age Subject  Marks
# 0    1         Vinit       Verulkar  21.000000      IS     99
# 1    2          Yash          Limje  20.000000   AR/VR     67
# 2    3        Gautam      Hargunani  20.000000   AR/VR     89
# 3    4        Nilesh      Bombatkar  22.000000      CC     78
# 4    5       Dhiraj       Hargunani  22.142857      CC     56
# 5    6         Rohit      Hargunani  19.000000      IS   1000
# 6    7         Mohit        Nikhade  23.000000      IS     78
# 7    8  Gopalkrushna          Kolhe  21.000000      CC     89
# 8    9         Sumit            Raj  17.000000      CC     56
# 9   10            Om         Mihani  24.000000      IS     89
# 10  11       Harshit     Khandelwal  24.000000   AR/VR     78
# 11  12       Atharva        Chandak  15.000000      CC     75
# 12  13         Tejas       Deshmukh  21.000000      IS     95
# 13  14      Bhavesh           Ingle  22.000000   AR/VR     68
# ...

# %%
n= int(res1.shape[0]/4);
m= int(3*res1.shape[0]/4);
result = res1.iloc[:,5:]
result1=result.sort_values("Marks",ignore_index=True)
q1= result1.at[n-1,"Marks"]
q3= result1.at[m-1,"Marks"]
final1= res1[(res1["Marks"] < upper) & (res1["Marks"] > lower)]

# %%
final1
# Out:
#     ID    First_name      Last_name        Age Subject  Marks
# 0    1         Vinit       Verulkar  21.000000      IS     99
# 1    2          Yash          Limje  20.000000   AR/VR     67
# 2    3        Gautam      Hargunani  20.000000   AR/VR     89
# 3    4        Nilesh      Bombatkar  22.000000      CC     78
# 4    5       Dhiraj       Hargunani  22.142857      CC     56
# 6    7         Mohit        Nikhade  23.000000      IS     78
# 7    8  Gopalkrushna          Kolhe  21.000000      CC     89
# 8    9         Sumit            Raj  17.000000      CC     56
# 9   10            Om         Mihani  24.000000      IS     89
# 10  11       Harshit     Khandelwal  24.000000   AR/VR     78
# 11  12       Atharva        Chandak  15.000000      CC     75
# 12  13         Tejas       Deshmukh  21.000000      IS     95
# 13  14      Bhavesh           Ingle  22.000000   AR/VR     68
# 14  15    Prathamesh       Kharpate  25.000000      CC     35
# ...

# %%
upper
# Out:
# 125.46142788881004

# %%
lower
# Out:
# 18.560794333412176

# %%
upper = res['Marks'].mean() + 3*res['Marks'].std()

lower = res['Marks'].mean() -3*res['Marks'].std()
final= res1[(res1["Marks"] < upper) & (res1["Marks"] > lower)]

# %%
final
# Out:
#     ID    First_name      Last_name        Age Subject  Marks
# 0    1         Vinit       Verulkar  21.000000      IS     99
# 1    2          Yash          Limje  20.000000   AR/VR     67
# 2    3        Gautam      Hargunani  20.000000   AR/VR     89
# 3    4        Nilesh      Bombatkar  22.000000      CC     78
# 4    5       Dhiraj       Hargunani  22.142857      CC     56
# 6    7         Mohit        Nikhade  23.000000      IS     78
# 7    8  Gopalkrushna          Kolhe  21.000000      CC     89
# 8    9         Sumit            Raj  17.000000      CC     56
# 9   10            Om         Mihani  24.000000      IS     89
# 10  11       Harshit     Khandelwal  24.000000   AR/VR     78
# 11  12       Atharva        Chandak  15.000000      CC     75
# 12  13         Tejas       Deshmukh  21.000000      IS     95
# 13  14      Bhavesh           Ingle  22.000000   AR/VR     68
# 14  15    Prathamesh       Kharpate  25.000000      CC     35
# ...

# %%
sns.displot(final, x="Marks", kind="kde")

# %%
final.skew().sort_values(ascending=False)
# Out:
# /tmp/ipykernel_2655/462040954.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   final.skew().sort_values(ascending=False)
# ID       0.370059
# Age      0.023740
# Marks   -0.390453
# dtype: float64

# %%
sns.displot(final, x="Age", kind="kde")

# %%
sns.displot(final, x="ID", kind="kde")

# %%
#log transformation method
final2=final.copy()
final2['Marks'] = np.log1p(final2["Marks"])
final2
# Out:
#     ID    First_name      Last_name        Age Subject     Marks
# 0    1         Vinit       Verulkar  21.000000      IS  4.605170
# 1    2          Yash          Limje  20.000000   AR/VR  4.219508
# 2    3        Gautam      Hargunani  20.000000   AR/VR  4.499810
# 3    4        Nilesh      Bombatkar  22.000000      CC  4.369448
# 4    5       Dhiraj       Hargunani  22.142857      CC  4.043051
# 6    7         Mohit        Nikhade  23.000000      IS  4.369448
# 7    8  Gopalkrushna          Kolhe  21.000000      CC  4.499810
# 8    9         Sumit            Raj  17.000000      CC  4.043051
# 9   10            Om         Mihani  24.000000      IS  4.499810
# 10  11       Harshit     Khandelwal  24.000000   AR/VR  4.369448
# 11  12       Atharva        Chandak  15.000000      CC  4.330733
# 12  13         Tejas       Deshmukh  21.000000      IS  4.564348
# 13  14      Bhavesh           Ingle  22.000000   AR/VR  4.234107
# ...

# %%
final2.skew().sort_values(ascending=False)
# Out:
# /tmp/ipykernel_2655/2109472322.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   final2.skew().sort_values(ascending=False)
# ID       0.370059
# Age      0.023740
# Marks   -0.879497
# dtype: float64

# %%
#box-cox method
from scipy.stats import boxcox
final3=final.copy()
val, lam= boxcox(final["Marks"])
final3['Marks'] = final3['Marks'].apply(lambda x: ((x**(lam))-1)/lam)
final3.skew().sort_values(ascending=False)
# Out:
# /tmp/ipykernel_2655/993154414.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   final3.skew().sort_values(ascending=False)
# ID       0.370059
# Age      0.023740
# Marks   -0.140758
# dtype: float64

# %%
sns.displot(final, x="ID", kind="kde")

# %%
#Squareroot method
final1['Marks']= final["Marks"]**(1/2)
final1
final1.skew().sort_values(ascending=False)
# Out:
# /tmp/ipykernel_2655/3339196939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final1['Marks']= final["Marks"]**(1/2)
# /tmp/ipykernel_2655/3339196939.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   final1.skew().sort_values(ascending=False)
# ID       0.370059
# Age      0.023740
# Marks   -0.627770
# dtype: float64

# %%
final3
# Out:
#     ID    First_name      Last_name        Age Subject       Marks
# 0    1         Vinit       Verulkar  21.000000      IS  895.193206
# 1    2          Yash          Limje  20.000000   AR/VR  483.023675
# 2    3        Gautam      Hargunani  20.000000   AR/VR  756.576514
# 3    4        Nilesh      Bombatkar  22.000000      CC  614.208643
# 4    5       Dhiraj       Hargunani  22.142857      CC  363.765482
# 6    7         Mohit        Nikhade  23.000000      IS  614.208643
# 7    8  Gopalkrushna          Kolhe  21.000000      CC  756.576514
# 8    9         Sumit            Raj  17.000000      CC  363.765482
# 9   10            Om         Mihani  24.000000      IS  756.576514
# 10  11       Harshit     Khandelwal  24.000000   AR/VR  614.208643
# 11  12       Atharva        Chandak  15.000000      CC  577.293463
# 12  13         Tejas       Deshmukh  21.000000      IS  838.723724
# 13  14      Bhavesh           Ingle  22.000000   AR/VR  494.469110
# ...

# %%
final3=final3.assign(Marks=(final3.Marks - final3['Marks'].min())/(final3['Marks'].max()-final3['Marks'].min()))
final3
# Out:
#     ID    First_name      Last_name        Age Subject     Marks
# 0    1         Vinit       Verulkar  21.000000      IS  1.000000
# 1    2          Yash          Limje  20.000000   AR/VR  0.429376
# 2    3        Gautam      Hargunani  20.000000   AR/VR  0.808094
# 3    4        Nilesh      Bombatkar  22.000000      CC  0.610994
# 4    5       Dhiraj       Hargunani  22.142857      CC  0.264270
# 6    7         Mohit        Nikhade  23.000000      IS  0.610994
# 7    8  Gopalkrushna          Kolhe  21.000000      CC  0.808094
# 8    9         Sumit            Raj  17.000000      CC  0.264270
# 9   10            Om         Mihani  24.000000      IS  0.808094
# 10  11       Harshit     Khandelwal  24.000000   AR/VR  0.610994
# 11  12       Atharva        Chandak  15.000000      CC  0.559887
# 12  13         Tejas       Deshmukh  21.000000      IS  0.921821
# 13  14      Bhavesh           Ingle  22.000000   AR/VR  0.445222
# ...

# %%
final1['Marks']= final1["Marks"]**(1/3)
final1.plot(kind = 'scatter', y = 'Marks',x  = 'ID')
# Out:
# /tmp/ipykernel_2655/180231265.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final1['Marks']= final1["Marks"]**(1/3)
# <AxesSubplot:xlabel='ID', ylabel='Marks'>
